# %% [markdown]
# # Abdel Latif abu ALi
# Computer science
# C3731204
# ======
# I am submitting Exam paper 1.

# %% [markdown]
# # I admire Programming
#
# ## from the moment I relised I had a passion for computer science I decided to go on an adventure to experience everything there is about programming
#
#
# ### It first started in the after school club for computer science where our teatcher would give us the computers have his coffee and we would sit and code in a game called **Scratch** this started with making a fox get a way from obstacles and this is why i fell in love with it would be quiet all the students have left and theres nothing but the program and you thats when i noticed that i'm in love with the peace that comes with programming.
#
# ***soon after we start web developing in college.***
# This turns into some serious work where my work can actually be useful and user friendly i start using
# - HTML
# - CSS
# - JSCRIPT

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is even.

# %%
def entered_function():
    numbers = [int(x) for x in input("Enter numbers separated by spaces: ").split()]
    if len(numbers) < 1 and len(numbers) > 100:
        return numbers
    else:
        print("Invalid list length. Please enter between 1 and 100 integers.")

# %%
# Out:
# 4553.0
# 4582120
# 8655.7
# 547828487456.6
